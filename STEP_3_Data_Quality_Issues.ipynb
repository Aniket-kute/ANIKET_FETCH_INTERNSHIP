# %%
import pandas as pd

# %%
users = pd.read_csv('usersd.csv')
users.dtypes
# Out:
# _id              object
# active             bool
# createdDate     float64
# lastLogin       float64
# role             object
# signUpSource     object
# state            object
# dtype: object

# %%
users.shape
# Out:
# (495, 7)

# %%
users.isnull().sum()
# Out:
# _id              0
# active           0
# createdDate      0
# lastLogin       62
# role             0
# signUpSource    48
# state           56
# dtype: int64

# %%
users.head(5)
# Out:
#                         _id  active   createdDate     lastLogin      role  \
# 0  5ff1e194b6a9d73a3a9f1052    True  1.609690e+12  1.609690e+12  consumer
# 1  5ff1e194b6a9d73a3a9f1052    True  1.609690e+12  1.609690e+12  consumer
# 2  5ff1e194b6a9d73a3a9f1052    True  1.609690e+12  1.609690e+12  consumer
# 3  5ff1e1eacfcf6c399c274ae6    True  1.609690e+12  1.609690e+12  consumer
# 4  5ff1e194b6a9d73a3a9f1052    True  1.609690e+12  1.609690e+12  consumer
#
#   signUpSource state
# 0        Email    WI
# 1        Email    WI
# 2        Email    WI
# 3        Email    WI
# 4        Email    WI

# %% [markdown]
# **Here we see in the above table that the _id has duplicate values**

# %%
userst = users[users.duplicated()]

# %% [markdown]
# **Showing all the duplicate values**

# %%
userst.head(5)
# Out:
#                         _id  active   createdDate     lastLogin      role  \
# 1  5ff1e194b6a9d73a3a9f1052    True  1.609690e+12  1.609690e+12  consumer
# 2  5ff1e194b6a9d73a3a9f1052    True  1.609690e+12  1.609690e+12  consumer
# 4  5ff1e194b6a9d73a3a9f1052    True  1.609690e+12  1.609690e+12  consumer
# 5  5ff1e194b6a9d73a3a9f1052    True  1.609690e+12  1.609690e+12  consumer
# 8  5ff1e194b6a9d73a3a9f1052    True  1.609690e+12  1.609690e+12  consumer
#
#   signUpSource state
# 1        Email    WI
# 2        Email    WI
# 4        Email    WI
# 5        Email    WI
# 8        Email    WI

# %%
userst.duplicated().sum()
# Out:
# 213

# %%
userst=userst.drop_duplicates()

# %%
userst
# Out:
#                           _id  active   createdDate     lastLogin  \
# 1    5ff1e194b6a9d73a3a9f1052    True  1.609690e+12  1.609690e+12
# 11   5ff1e1eacfcf6c399c274ae6    True  1.609690e+12  1.609690e+12
# 24   5ff370c562fde912123a5e0e    True  1.609790e+12  1.609790e+12
# 26   5ff36d0362fde912123a5535    True  1.609790e+12  1.609790e+12
# 27   5ff36be7135e7011bcb856d3    True  1.609790e+12  1.609790e+12
# ..                        ...     ...           ...           ...
# 429  5fb0a078be5fc9775c1f3945    True  1.605410e+12  1.613150e+12
# 433  5fbc35711d967d1222cbfefc    True  1.606170e+12  1.614310e+12
# 436  5fc961c3b8cfca11a077dd33    True  1.607030e+12  1.614380e+12
# 457  5fa41775898c7a11a6bcef3e    True  1.604590e+12  1.614870e+12
# 476  54943462e4b07e684157a532    True  1.419000e+12  1.614960e+12
#
#             role signUpSource state
# 1       consumer        Email    WI
# 11      consumer        Email    WI
# 24      consumer        Email    WI
# ...

# %%
userst=userst.drop_duplicates(subset = ['_id'])

# %%
userst.head(5)
# Out:
#                          _id  active   createdDate     lastLogin      role  \
# 1   5ff1e194b6a9d73a3a9f1052    True  1.609690e+12  1.609690e+12  consumer
# 11  5ff1e1eacfcf6c399c274ae6    True  1.609690e+12  1.609690e+12  consumer
# 24  5ff370c562fde912123a5e0e    True  1.609790e+12  1.609790e+12  consumer
# 26  5ff36d0362fde912123a5535    True  1.609790e+12  1.609790e+12  consumer
# 27  5ff36be7135e7011bcb856d3    True  1.609790e+12  1.609790e+12  consumer
#
#    signUpSource state
# 1         Email    WI
# 11        Email    WI
# 24        Email    WI
# 26        Email    WI
# 27        Email    WI

# %%
userst.isnull().sum()
# Out:
# _id              0
# active           0
# createdDate      0
# lastLogin       10
# role             0
# signUpSource     3
# state            6
# dtype: int64

# %%
import numpy as np

# %%
userst= userst.replace( np.NaN, regex=True)

# %%
userst
# Out:
#                           _id  active   createdDate     lastLogin  \
# 1    5ff1e194b6a9d73a3a9f1052    True  1.609690e+12  1.609690e+12
# 11   5ff1e1eacfcf6c399c274ae6    True  1.609690e+12  1.609690e+12
# 24   5ff370c562fde912123a5e0e    True  1.609790e+12  1.609790e+12
# 26   5ff36d0362fde912123a5535    True  1.609790e+12  1.609790e+12
# 27   5ff36be7135e7011bcb856d3    True  1.609790e+12  1.609790e+12
# ..                        ...     ...           ...           ...
# 429  5fb0a078be5fc9775c1f3945    True  1.605410e+12  1.613150e+12
# 433  5fbc35711d967d1222cbfefc    True  1.606170e+12  1.614310e+12
# 436  5fc961c3b8cfca11a077dd33    True  1.607030e+12  1.614380e+12
# 457  5fa41775898c7a11a6bcef3e    True  1.604590e+12  1.614870e+12
# 476  54943462e4b07e684157a532    True  1.419000e+12  1.614960e+12
#
#             role signUpSource state
# 1       consumer        Email    WI
# 11      consumer        Email    WI
# 24      consumer        Email    WI
# ...
